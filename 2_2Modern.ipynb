# %% [markdown]
# # Download Dataset

# %%
# Download the KITTI dataset
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_semantics.zip
# Out:
# --2025-03-10 00:04:40--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_semantics.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.169.169, 3.5.134.27, 3.5.135.122, ...
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.169.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 327699796 (313M) [application/zip]
# Saving to: ‘data_semantics.zip’
#
# data_semantics.zip  100%[===================>] 312.52M  25.2MB/s    in 13s
#
# 2025-03-10 00:04:54 (23.8 MB/s) - ‘data_semantics.zip’ saved [327699796/327699796]

# %% [markdown]
# # Import Libraries

# %%
# !unzip data_semantics.zip
# Out:
# Archive:  data_semantics.zip
#    creating: testing/
#    creating: testing/image_2/
#   inflating: testing/image_2/000000_10.png
#   inflating: testing/image_2/000001_10.png
#   inflating: testing/image_2/000002_10.png
#   inflating: testing/image_2/000003_10.png
#   inflating: testing/image_2/000004_10.png
#   inflating: testing/image_2/000005_10.png
#   inflating: testing/image_2/000006_10.png
#   inflating: testing/image_2/000007_10.png
#   inflating: testing/image_2/000008_10.png
#   inflating: testing/image_2/000009_10.png
#   inflating: testing/image_2/000010_10.png
#   inflating: testing/image_2/000011_10.png
#   inflating: testing/image_2/000012_10.png
#   inflating: testing/image_2/000013_10.png
#   inflating: testing/image_2/000014_10.png
#   inflating: testing/image_2/000015_10.png
#   inflating: testing/image_2/000016_10.png
#   inflating: testing/image_2/000017_10.png
#   inflating: testing/image_2/000018_10.png
#   inflating: testing/image_2/000019_10.png
#   inflating: testing/image_2/000020_10.png
#   inflating: testing/image_2/000021_10.png
#   inflating: testing/image_2/000022_10.png
#   inflating: testing/image_2/000023_10.png
#   inflating: testing/image_2/000024_10.png
#   inflating: testing/image_2/000025_10.png
#   inflating: testing/image_2/000026_10.png
#   inflating: testing/image_2/000027_10.png
#   inflating: testing/image_2/000028_10.png
#   inflating: testing/image_2/000029_10.png
#   inflating: testing/image_2/000030_10.png
#   inflating: testing/image_2/000031_10.png
#   inflating: testing/image_2/000032_10.png
#   inflating: testing/image_2/000033_10.png
#   inflating: testing/image_2/000034_10.png
#   inflating: testing/image_2/000035_10.png
#   inflating: testing/image_2/000036_10.png
#   inflating: testing/image_2/000037_10.png
#   inflating: testing/image_2/000038_10.png
#   inflating: testing/image_2/000039_10.png
#   inflating: testing/image_2/000040_10.png
#   inflating: testing/image_2/000041_10.png
#   inflating: testing/image_2/000042_10.png
#   inflating: testing/image_2/000043_10.png
#   inflating: testing/image_2/000044_10.png
#   inflating: testing/image_2/000045_10.png
#   inflating: testing/image_2/000046_10.png
#   inflating: testing/image_2/000047_10.png
#   inflating: testing/image_2/000048_10.png
#   inflating: testing/image_2/000049_10.png
#   inflating: testing/image_2/000050_10.png
#   inflating: testing/image_2/000051_10.png
#   inflating: testing/image_2/000052_10.png
#   inflating: testing/image_2/000053_10.png
#   inflating: testing/image_2/000054_10.png
#   inflating: testing/image_2/000055_10.png
#   inflating: testing/image_2/000056_10.png
#   inflating: testing/image_2/000057_10.png
#   inflating: testing/image_2/000058_10.png
#   inflating: testing/image_2/000059_10.png
#   inflating: testing/image_2/000060_10.png
#   inflating: testing/image_2/000061_10.png
#   inflating: testing/image_2/000062_10.png
#   inflating: testing/image_2/000063_10.png
#   inflating: testing/image_2/000064_10.png
#   inflating: testing/image_2/000065_10.png
#   inflating: testing/image_2/000066_10.png
#   inflating: testing/image_2/000067_10.png
#   inflating: testing/image_2/000068_10.png
#   inflating: testing/image_2/000069_10.png
#   inflating: testing/image_2/000070_10.png
#   inflating: testing/image_2/000071_10.png
#   inflating: testing/image_2/000072_10.png
#   inflating: testing/image_2/000073_10.png
#   inflating: testing/image_2/000074_10.png
#   inflating: testing/image_2/000075_10.png
#   inflating: testing/image_2/000076_10.png
#   inflating: testing/image_2/000077_10.png
#   inflating: testing/image_2/000078_10.png
#   inflating: testing/image_2/000079_10.png
#   inflating: testing/image_2/000080_10.png
#   inflating: testing/image_2/000081_10.png
#   inflating: testing/image_2/000082_10.png
#   inflating: testing/image_2/000083_10.png
#   inflating: testing/image_2/000084_10.png
#   inflating: testing/image_2/000085_10.png
#   inflating: testing/image_2/000086_10.png
#   inflating: testing/image_2/000087_10.png
#   inflating: testing/image_2/000088_10.png
#   inflating: testing/image_2/000089_10.png
#   inflating: testing/image_2/000090_10.png
#   inflating: testing/image_2/000091_10.png
#   inflating: testing/image_2/000092_10.png
#   inflating: testing/image_2/000093_10.png
#   inflating: testing/image_2/000094_10.png
#   inflating: testing/image_2/000095_10.png
#   inflating: testing/image_2/000096_10.png
#   inflating: testing/image_2/000097_10.png
#   inflating: testing/image_2/000098_10.png
#   inflating: testing/image_2/000099_10.png
#   inflating: testing/image_2/000100_10.png
#   inflating: testing/image_2/000101_10.png
#   inflating: testing/image_2/000102_10.png
#   inflating: testing/image_2/000103_10.png
#   inflating: testing/image_2/000104_10.png
#   inflating: testing/image_2/000105_10.png
#   inflating: testing/image_2/000106_10.png
#   inflating: testing/image_2/000107_10.png
#   inflating: testing/image_2/000108_10.png
#   inflating: testing/image_2/000109_10.png
#   inflating: testing/image_2/000110_10.png
#   inflating: testing/image_2/000111_10.png
#   inflating: testing/image_2/000112_10.png
#   inflating: testing/image_2/000113_10.png
#   inflating: testing/image_2/000114_10.png
#   inflating: testing/image_2/000115_10.png
#   inflating: testing/image_2/000116_10.png
#   inflating: testing/image_2/000117_10.png
#   inflating: testing/image_2/000118_10.png
#   inflating: testing/image_2/000119_10.png
#   inflating: testing/image_2/000120_10.png
#   inflating: testing/image_2/000121_10.png
#   inflating: testing/image_2/000122_10.png
#   inflating: testing/image_2/000123_10.png
#   inflating: testing/image_2/000124_10.png
#   inflating: testing/image_2/000125_10.png
#   inflating: testing/image_2/000126_10.png
#   inflating: testing/image_2/000127_10.png
#   inflating: testing/image_2/000128_10.png
#   inflating: testing/image_2/000129_10.png
#   inflating: testing/image_2/000130_10.png
#   inflating: testing/image_2/000131_10.png
#   inflating: testing/image_2/000132_10.png
#   inflating: testing/image_2/000133_10.png
#   inflating: testing/image_2/000134_10.png
#   inflating: testing/image_2/000135_10.png
#   inflating: testing/image_2/000136_10.png
#   inflating: testing/image_2/000137_10.png
#   inflating: testing/image_2/000138_10.png
#   inflating: testing/image_2/000139_10.png
#   inflating: testing/image_2/000140_10.png
#   inflating: testing/image_2/000141_10.png
#   inflating: testing/image_2/000142_10.png
#   inflating: testing/image_2/000143_10.png
#   inflating: testing/image_2/000144_10.png
#   inflating: testing/image_2/000145_10.png
#   inflating: testing/image_2/000146_10.png
#   inflating: testing/image_2/000147_10.png
#   inflating: testing/image_2/000148_10.png
#   inflating: testing/image_2/000149_10.png
#   inflating: testing/image_2/000150_10.png
#   inflating: testing/image_2/000151_10.png
#   inflating: testing/image_2/000152_10.png
#   inflating: testing/image_2/000153_10.png
#   inflating: testing/image_2/000154_10.png
#   inflating: testing/image_2/000155_10.png
#   inflating: testing/image_2/000156_10.png
#   inflating: testing/image_2/000157_10.png
#   inflating: testing/image_2/000158_10.png
#   inflating: testing/image_2/000159_10.png
#   inflating: testing/image_2/000160_10.png
#   inflating: testing/image_2/000161_10.png
#   inflating: testing/image_2/000162_10.png
#   inflating: testing/image_2/000163_10.png
#   inflating: testing/image_2/000164_10.png
#   inflating: testing/image_2/000165_10.png
#   inflating: testing/image_2/000166_10.png
#   inflating: testing/image_2/000167_10.png
#   inflating: testing/image_2/000168_10.png
#   inflating: testing/image_2/000169_10.png
#   inflating: testing/image_2/000170_10.png
#   inflating: testing/image_2/000171_10.png
#   inflating: testing/image_2/000172_10.png
#   inflating: testing/image_2/000173_10.png
#   inflating: testing/image_2/000174_10.png
#   inflating: testing/image_2/000175_10.png
#   inflating: testing/image_2/000176_10.png
#   inflating: testing/image_2/000177_10.png
#   inflating: testing/image_2/000178_10.png
#   inflating: testing/image_2/000179_10.png
#   inflating: testing/image_2/000180_10.png
#   inflating: testing/image_2/000181_10.png
#   inflating: testing/image_2/000182_10.png
#   inflating: testing/image_2/000183_10.png
#   inflating: testing/image_2/000184_10.png
#   inflating: testing/image_2/000185_10.png
#   inflating: testing/image_2/000186_10.png
#   inflating: testing/image_2/000187_10.png
#   inflating: testing/image_2/000188_10.png
#   inflating: testing/image_2/000189_10.png
#   inflating: testing/image_2/000190_10.png
#   inflating: testing/image_2/000191_10.png
#   inflating: testing/image_2/000192_10.png
#   inflating: testing/image_2/000193_10.png
#   inflating: testing/image_2/000194_10.png
#   inflating: testing/image_2/000195_10.png
#   inflating: testing/image_2/000196_10.png
#   inflating: testing/image_2/000197_10.png
#   inflating: testing/image_2/000198_10.png
#   inflating: testing/image_2/000199_10.png
#    creating: training/
#    creating: training/image_2/
#   inflating: training/image_2/000000_10.png
#   inflating: training/image_2/000001_10.png
#   inflating: training/image_2/000002_10.png
#   inflating: training/image_2/000003_10.png
#   inflating: training/image_2/000004_10.png
#   inflating: training/image_2/000005_10.png
#   inflating: training/image_2/000006_10.png
#   inflating: training/image_2/000007_10.png
#   inflating: training/image_2/000008_10.png
#   inflating: training/image_2/000009_10.png
#   inflating: training/image_2/000010_10.png
#   inflating: training/image_2/000011_10.png
#   inflating: training/image_2/000012_10.png
#   inflating: training/image_2/000013_10.png
#   inflating: training/image_2/000014_10.png
#   inflating: training/image_2/000015_10.png
#   inflating: training/image_2/000016_10.png
#   inflating: training/image_2/000017_10.png
#   inflating: training/image_2/000018_10.png
#   inflating: training/image_2/000019_10.png
#   inflating: training/image_2/000020_10.png
#   inflating: training/image_2/000021_10.png
#   inflating: training/image_2/000022_10.png
#   inflating: training/image_2/000023_10.png
#   inflating: training/image_2/000024_10.png
#   inflating: training/image_2/000025_10.png
#   inflating: training/image_2/000026_10.png
#   inflating: training/image_2/000027_10.png
#   inflating: training/image_2/000028_10.png
#   inflating: training/image_2/000029_10.png
#   inflating: training/image_2/000030_10.png
#   inflating: training/image_2/000031_10.png
#   inflating: training/image_2/000032_10.png
#   inflating: training/image_2/000033_10.png
#   inflating: training/image_2/000034_10.png
#   inflating: training/image_2/000035_10.png
#   inflating: training/image_2/000036_10.png
#   inflating: training/image_2/000037_10.png
#   inflating: training/image_2/000038_10.png
#   inflating: training/image_2/000039_10.png
#   inflating: training/image_2/000040_10.png
#   inflating: training/image_2/000041_10.png
#   inflating: training/image_2/000042_10.png
#   inflating: training/image_2/000043_10.png
#   inflating: training/image_2/000044_10.png
#   inflating: training/image_2/000045_10.png
#   inflating: training/image_2/000046_10.png
#   inflating: training/image_2/000047_10.png
#   inflating: training/image_2/000048_10.png
#   inflating: training/image_2/000049_10.png
#   inflating: training/image_2/000050_10.png
#   inflating: training/image_2/000051_10.png
#   inflating: training/image_2/000052_10.png
#   inflating: training/image_2/000053_10.png
#   inflating: training/image_2/000054_10.png
#   inflating: training/image_2/000055_10.png
#   inflating: training/image_2/000056_10.png
#   inflating: training/image_2/000057_10.png
#   inflating: training/image_2/000058_10.png
#   inflating: training/image_2/000059_10.png
#   inflating: training/image_2/000060_10.png
#   inflating: training/image_2/000061_10.png
#   inflating: training/image_2/000062_10.png
#   inflating: training/image_2/000063_10.png
#   inflating: training/image_2/000064_10.png
#   inflating: training/image_2/000065_10.png
#   inflating: training/image_2/000066_10.png
#   inflating: training/image_2/000067_10.png
#   inflating: training/image_2/000068_10.png
#   inflating: training/image_2/000069_10.png
#   inflating: training/image_2/000070_10.png
#   inflating: training/image_2/000071_10.png
#   inflating: training/image_2/000072_10.png
#   inflating: training/image_2/000073_10.png
#   inflating: training/image_2/000074_10.png
#   inflating: training/image_2/000075_10.png
#   inflating: training/image_2/000076_10.png
#   inflating: training/image_2/000077_10.png
#   inflating: training/image_2/000078_10.png
#   inflating: training/image_2/000079_10.png
#   inflating: training/image_2/000080_10.png
#   inflating: training/image_2/000081_10.png
#   inflating: training/image_2/000082_10.png
#   inflating: training/image_2/000083_10.png
#   inflating: training/image_2/000084_10.png
#   inflating: training/image_2/000085_10.png
#   inflating: training/image_2/000086_10.png
#   inflating: training/image_2/000087_10.png
#   inflating: training/image_2/000088_10.png
#   inflating: training/image_2/000089_10.png
#   inflating: training/image_2/000090_10.png
#   inflating: training/image_2/000091_10.png
#   inflating: training/image_2/000092_10.png
#   inflating: training/image_2/000093_10.png
#   inflating: training/image_2/000094_10.png
#   inflating: training/image_2/000095_10.png
#   inflating: training/image_2/000096_10.png
#   inflating: training/image_2/000097_10.png
#   inflating: training/image_2/000098_10.png
#   inflating: training/image_2/000099_10.png
#   inflating: training/image_2/000100_10.png
#   inflating: training/image_2/000101_10.png
#   inflating: training/image_2/000102_10.png
#   inflating: training/image_2/000103_10.png
#  extracting: training/image_2/000104_10.png
#   inflating: training/image_2/000105_10.png
#   inflating: training/image_2/000106_10.png
#   inflating: training/image_2/000107_10.png
#   inflating: training/image_2/000108_10.png
#   inflating: training/image_2/000109_10.png
#   inflating: training/image_2/000110_10.png
#   inflating: training/image_2/000111_10.png
#   inflating: training/image_2/000112_10.png
#   inflating: training/image_2/000113_10.png
#   inflating: training/image_2/000114_10.png
#   inflating: training/image_2/000115_10.png
#   inflating: training/image_2/000116_10.png
#   inflating: training/image_2/000117_10.png
#   inflating: training/image_2/000118_10.png
#   inflating: training/image_2/000119_10.png
#   inflating: training/image_2/000120_10.png
#   inflating: training/image_2/000121_10.png
#   inflating: training/image_2/000122_10.png
#   inflating: training/image_2/000123_10.png
#   inflating: training/image_2/000124_10.png
#   inflating: training/image_2/000125_10.png
#   inflating: training/image_2/000126_10.png
#   inflating: training/image_2/000127_10.png
#   inflating: training/image_2/000128_10.png
#   inflating: training/image_2/000129_10.png
#   inflating: training/image_2/000130_10.png
#   inflating: training/image_2/000131_10.png
#   inflating: training/image_2/000132_10.png
#   inflating: training/image_2/000133_10.png
#   inflating: training/image_2/000134_10.png
#   inflating: training/image_2/000135_10.png
#   inflating: training/image_2/000136_10.png
#   inflating: training/image_2/000137_10.png
#   inflating: training/image_2/000138_10.png
#   inflating: training/image_2/000139_10.png
#   inflating: training/image_2/000140_10.png
#   inflating: training/image_2/000141_10.png
#   inflating: training/image_2/000142_10.png
#   inflating: training/image_2/000143_10.png
#   inflating: training/image_2/000144_10.png
#   inflating: training/image_2/000145_10.png
#   inflating: training/image_2/000146_10.png
#   inflating: training/image_2/000147_10.png
#   inflating: training/image_2/000148_10.png
#   inflating: training/image_2/000149_10.png
#   inflating: training/image_2/000150_10.png
#   inflating: training/image_2/000151_10.png
#   inflating: training/image_2/000152_10.png
#   inflating: training/image_2/000153_10.png
#   inflating: training/image_2/000154_10.png
#   inflating: training/image_2/000155_10.png
#   inflating: training/image_2/000156_10.png
#   inflating: training/image_2/000157_10.png
#   inflating: training/image_2/000158_10.png
#   inflating: training/image_2/000159_10.png
#   inflating: training/image_2/000160_10.png
#   inflating: training/image_2/000161_10.png
#   inflating: training/image_2/000162_10.png
#   inflating: training/image_2/000163_10.png
#   inflating: training/image_2/000164_10.png
#   inflating: training/image_2/000165_10.png
#   inflating: training/image_2/000166_10.png
#   inflating: training/image_2/000167_10.png
#   inflating: training/image_2/000168_10.png
#   inflating: training/image_2/000169_10.png
#   inflating: training/image_2/000170_10.png
#   inflating: training/image_2/000171_10.png
#   inflating: training/image_2/000172_10.png
#   inflating: training/image_2/000173_10.png
#   inflating: training/image_2/000174_10.png
#   inflating: training/image_2/000175_10.png
#   inflating: training/image_2/000176_10.png
#   inflating: training/image_2/000177_10.png
#   inflating: training/image_2/000178_10.png
#   inflating: training/image_2/000179_10.png
#   inflating: training/image_2/000180_10.png
#   inflating: training/image_2/000181_10.png
#   inflating: training/image_2/000182_10.png
#   inflating: training/image_2/000183_10.png
#   inflating: training/image_2/000184_10.png
#   inflating: training/image_2/000185_10.png
#   inflating: training/image_2/000186_10.png
#   inflating: training/image_2/000187_10.png
#   inflating: training/image_2/000188_10.png
#   inflating: training/image_2/000189_10.png
#   inflating: training/image_2/000190_10.png
#   inflating: training/image_2/000191_10.png
#   inflating: training/image_2/000192_10.png
#   inflating: training/image_2/000193_10.png
#   inflating: training/image_2/000194_10.png
#   inflating: training/image_2/000195_10.png
#   inflating: training/image_2/000196_10.png
#   inflating: training/image_2/000197_10.png
#   inflating: training/image_2/000198_10.png
#   inflating: training/image_2/000199_10.png
#    creating: training/instance/
#   inflating: training/instance/000000_10.png
#   inflating: training/instance/000001_10.png
#   inflating: training/instance/000002_10.png
#   inflating: training/instance/000003_10.png
#   inflating: training/instance/000004_10.png
#   inflating: training/instance/000005_10.png
#   inflating: training/instance/000006_10.png
#   inflating: training/instance/000007_10.png
#   inflating: training/instance/000008_10.png
#   inflating: training/instance/000009_10.png
#   inflating: training/instance/000010_10.png
#   inflating: training/instance/000011_10.png
#   inflating: training/instance/000012_10.png
#   inflating: training/instance/000013_10.png
#   inflating: training/instance/000014_10.png
#   inflating: training/instance/000015_10.png
#   inflating: training/instance/000016_10.png
#   inflating: training/instance/000017_10.png
#   inflating: training/instance/000018_10.png
#   inflating: training/instance/000019_10.png
#   inflating: training/instance/000020_10.png
#   inflating: training/instance/000021_10.png
#   inflating: training/instance/000022_10.png
#   inflating: training/instance/000023_10.png
#   inflating: training/instance/000024_10.png
#   inflating: training/instance/000025_10.png
#   inflating: training/instance/000026_10.png
#   inflating: training/instance/000027_10.png
#   inflating: training/instance/000028_10.png
#   inflating: training/instance/000029_10.png
#   inflating: training/instance/000030_10.png
#   inflating: training/instance/000031_10.png
#   inflating: training/instance/000032_10.png
#   inflating: training/instance/000033_10.png
#   inflating: training/instance/000034_10.png
#   inflating: training/instance/000035_10.png
#   inflating: training/instance/000036_10.png
#   inflating: training/instance/000037_10.png
#   inflating: training/instance/000038_10.png
#   inflating: training/instance/000039_10.png
#   inflating: training/instance/000040_10.png
#   inflating: training/instance/000041_10.png
#   inflating: training/instance/000042_10.png
#   inflating: training/instance/000043_10.png
#   inflating: training/instance/000044_10.png
#   inflating: training/instance/000045_10.png
#   inflating: training/instance/000046_10.png
#   inflating: training/instance/000047_10.png
#   inflating: training/instance/000048_10.png
#   inflating: training/instance/000049_10.png
#   inflating: training/instance/000050_10.png
#   inflating: training/instance/000051_10.png
#   inflating: training/instance/000052_10.png
#   inflating: training/instance/000053_10.png
#   inflating: training/instance/000054_10.png
#   inflating: training/instance/000055_10.png
#   inflating: training/instance/000056_10.png
#   inflating: training/instance/000057_10.png
#   inflating: training/instance/000058_10.png
#   inflating: training/instance/000059_10.png
#   inflating: training/instance/000060_10.png
#   inflating: training/instance/000061_10.png
#   inflating: training/instance/000062_10.png
#   inflating: training/instance/000063_10.png
#   inflating: training/instance/000064_10.png
#   inflating: training/instance/000065_10.png
#   inflating: training/instance/000066_10.png
#   inflating: training/instance/000067_10.png
#   inflating: training/instance/000068_10.png
#   inflating: training/instance/000069_10.png
#   inflating: training/instance/000070_10.png
#   inflating: training/instance/000071_10.png
#   inflating: training/instance/000072_10.png
#   inflating: training/instance/000073_10.png
#   inflating: training/instance/000074_10.png
#   inflating: training/instance/000075_10.png
#   inflating: training/instance/000076_10.png
#   inflating: training/instance/000077_10.png
#   inflating: training/instance/000078_10.png
#   inflating: training/instance/000079_10.png
#   inflating: training/instance/000080_10.png
#   inflating: training/instance/000081_10.png
#   inflating: training/instance/000082_10.png
#   inflating: training/instance/000083_10.png
#   inflating: training/instance/000084_10.png
#   inflating: training/instance/000085_10.png
#   inflating: training/instance/000086_10.png
#   inflating: training/instance/000087_10.png
#   inflating: training/instance/000088_10.png
#   inflating: training/instance/000089_10.png
#   inflating: training/instance/000090_10.png
#   inflating: training/instance/000091_10.png
#   inflating: training/instance/000092_10.png
#   inflating: training/instance/000093_10.png
#   inflating: training/instance/000094_10.png
#   inflating: training/instance/000095_10.png
#   inflating: training/instance/000096_10.png
#   inflating: training/instance/000097_10.png
#   inflating: training/instance/000098_10.png
#   inflating: training/instance/000099_10.png
#   inflating: training/instance/000100_10.png
#   inflating: training/instance/000101_10.png
#   inflating: training/instance/000102_10.png
#   inflating: training/instance/000103_10.png
#   inflating: training/instance/000104_10.png
#   inflating: training/instance/000105_10.png
#   inflating: training/instance/000106_10.png
#   inflating: training/instance/000107_10.png
#   inflating: training/instance/000108_10.png
#   inflating: training/instance/000109_10.png
#   inflating: training/instance/000110_10.png
#   inflating: training/instance/000111_10.png
#   inflating: training/instance/000112_10.png
#   inflating: training/instance/000113_10.png
#   inflating: training/instance/000114_10.png
#   inflating: training/instance/000115_10.png
#   inflating: training/instance/000116_10.png
#   inflating: training/instance/000117_10.png
#   inflating: training/instance/000118_10.png
#   inflating: training/instance/000119_10.png
#   inflating: training/instance/000120_10.png
#   inflating: training/instance/000121_10.png
#   inflating: training/instance/000122_10.png
#   inflating: training/instance/000123_10.png
#   inflating: training/instance/000124_10.png
#   inflating: training/instance/000125_10.png
#   inflating: training/instance/000126_10.png
#   inflating: training/instance/000127_10.png
#   inflating: training/instance/000128_10.png
#   inflating: training/instance/000129_10.png
#   inflating: training/instance/000130_10.png
#   inflating: training/instance/000131_10.png
#   inflating: training/instance/000132_10.png
#   inflating: training/instance/000133_10.png
#   inflating: training/instance/000134_10.png
#   inflating: training/instance/000135_10.png
#   inflating: training/instance/000136_10.png
#   inflating: training/instance/000137_10.png
#   inflating: training/instance/000138_10.png
#   inflating: training/instance/000139_10.png
#   inflating: training/instance/000140_10.png
#   inflating: training/instance/000141_10.png
#   inflating: training/instance/000142_10.png
#   inflating: training/instance/000143_10.png
#   inflating: training/instance/000144_10.png
#   inflating: training/instance/000145_10.png
#   inflating: training/instance/000146_10.png
#   inflating: training/instance/000147_10.png
#   inflating: training/instance/000148_10.png
#   inflating: training/instance/000149_10.png
#   inflating: training/instance/000150_10.png
#   inflating: training/instance/000151_10.png
#   inflating: training/instance/000152_10.png
#   inflating: training/instance/000153_10.png
#   inflating: training/instance/000154_10.png
#   inflating: training/instance/000155_10.png
#   inflating: training/instance/000156_10.png
#   inflating: training/instance/000157_10.png
#   inflating: training/instance/000158_10.png
#   inflating: training/instance/000159_10.png
#   inflating: training/instance/000160_10.png
#   inflating: training/instance/000161_10.png
#   inflating: training/instance/000162_10.png
#   inflating: training/instance/000163_10.png
#   inflating: training/instance/000164_10.png
#   inflating: training/instance/000165_10.png
#   inflating: training/instance/000166_10.png
#   inflating: training/instance/000167_10.png
#   inflating: training/instance/000168_10.png
#   inflating: training/instance/000169_10.png
#   inflating: training/instance/000170_10.png
#   inflating: training/instance/000171_10.png
#   inflating: training/instance/000172_10.png
#   inflating: training/instance/000173_10.png
#   inflating: training/instance/000174_10.png
#   inflating: training/instance/000175_10.png
#   inflating: training/instance/000176_10.png
#   inflating: training/instance/000177_10.png
#   inflating: training/instance/000178_10.png
#   inflating: training/instance/000179_10.png
#   inflating: training/instance/000180_10.png
#   inflating: training/instance/000181_10.png
#   inflating: training/instance/000182_10.png
#   inflating: training/instance/000183_10.png
#   inflating: training/instance/000184_10.png
#   inflating: training/instance/000185_10.png
#   inflating: training/instance/000186_10.png
#   inflating: training/instance/000187_10.png
#   inflating: training/instance/000188_10.png
#   inflating: training/instance/000189_10.png
#   inflating: training/instance/000190_10.png
#   inflating: training/instance/000191_10.png
#   inflating: training/instance/000192_10.png
#   inflating: training/instance/000193_10.png
#   inflating: training/instance/000194_10.png
#   inflating: training/instance/000195_10.png
#   inflating: training/instance/000196_10.png
#   inflating: training/instance/000197_10.png
#   inflating: training/instance/000198_10.png
#   inflating: training/instance/000199_10.png
#    creating: training/semantic/
#   inflating: training/semantic/000000_10.png
#   inflating: training/semantic/000001_10.png
#   inflating: training/semantic/000002_10.png
#   inflating: training/semantic/000003_10.png
#   inflating: training/semantic/000004_10.png
#   inflating: training/semantic/000005_10.png
#   inflating: training/semantic/000006_10.png
#   inflating: training/semantic/000007_10.png
#   inflating: training/semantic/000008_10.png
#   inflating: training/semantic/000009_10.png
#   inflating: training/semantic/000010_10.png
#   inflating: training/semantic/000011_10.png
#  extracting: training/semantic/000012_10.png
#   inflating: training/semantic/000013_10.png
#   inflating: training/semantic/000014_10.png
#   inflating: training/semantic/000015_10.png
#   inflating: training/semantic/000016_10.png
#   inflating: training/semantic/000017_10.png
#   inflating: training/semantic/000018_10.png
#   inflating: training/semantic/000019_10.png
#   inflating: training/semantic/000020_10.png
#   inflating: training/semantic/000021_10.png
#   inflating: training/semantic/000022_10.png
#   inflating: training/semantic/000023_10.png
#   inflating: training/semantic/000024_10.png
#   inflating: training/semantic/000025_10.png
#   inflating: training/semantic/000026_10.png
#   inflating: training/semantic/000027_10.png
#   inflating: training/semantic/000028_10.png
#   inflating: training/semantic/000029_10.png
#   inflating: training/semantic/000030_10.png
#   inflating: training/semantic/000031_10.png
#   inflating: training/semantic/000032_10.png
#   inflating: training/semantic/000033_10.png
#   inflating: training/semantic/000034_10.png
#   inflating: training/semantic/000035_10.png
#   inflating: training/semantic/000036_10.png
#   inflating: training/semantic/000037_10.png
#   inflating: training/semantic/000038_10.png
#   inflating: training/semantic/000039_10.png
#   inflating: training/semantic/000040_10.png
#   inflating: training/semantic/000041_10.png
#   inflating: training/semantic/000042_10.png
#   inflating: training/semantic/000043_10.png
#   inflating: training/semantic/000044_10.png
#   inflating: training/semantic/000045_10.png
#   inflating: training/semantic/000046_10.png
#   inflating: training/semantic/000047_10.png
#   inflating: training/semantic/000048_10.png
#   inflating: training/semantic/000049_10.png
#   inflating: training/semantic/000050_10.png
#   inflating: training/semantic/000051_10.png
#   inflating: training/semantic/000052_10.png
#   inflating: training/semantic/000053_10.png
#   inflating: training/semantic/000054_10.png
#   inflating: training/semantic/000055_10.png
#   inflating: training/semantic/000056_10.png
#   inflating: training/semantic/000057_10.png
#   inflating: training/semantic/000058_10.png
#   inflating: training/semantic/000059_10.png
#   inflating: training/semantic/000060_10.png
#   inflating: training/semantic/000061_10.png
#   inflating: training/semantic/000062_10.png
#   inflating: training/semantic/000063_10.png
#   inflating: training/semantic/000064_10.png
#   inflating: training/semantic/000065_10.png
#   inflating: training/semantic/000066_10.png
#   inflating: training/semantic/000067_10.png
#   inflating: training/semantic/000068_10.png
#   inflating: training/semantic/000069_10.png
#   inflating: training/semantic/000070_10.png
#   inflating: training/semantic/000071_10.png
#   inflating: training/semantic/000072_10.png
#   inflating: training/semantic/000073_10.png
#   inflating: training/semantic/000074_10.png
#   inflating: training/semantic/000075_10.png
#   inflating: training/semantic/000076_10.png
#   inflating: training/semantic/000077_10.png
#   inflating: training/semantic/000078_10.png
#   inflating: training/semantic/000079_10.png
#   inflating: training/semantic/000080_10.png
#   inflating: training/semantic/000081_10.png
#   inflating: training/semantic/000082_10.png
#   inflating: training/semantic/000083_10.png
#   inflating: training/semantic/000084_10.png
#   inflating: training/semantic/000085_10.png
#   inflating: training/semantic/000086_10.png
#   inflating: training/semantic/000087_10.png
#   inflating: training/semantic/000088_10.png
#   inflating: training/semantic/000089_10.png
#   inflating: training/semantic/000090_10.png
#   inflating: training/semantic/000091_10.png
#   inflating: training/semantic/000092_10.png
#   inflating: training/semantic/000093_10.png
#   inflating: training/semantic/000094_10.png
#   inflating: training/semantic/000095_10.png
#   inflating: training/semantic/000096_10.png
#   inflating: training/semantic/000097_10.png
#   inflating: training/semantic/000098_10.png
#   inflating: training/semantic/000099_10.png
#   inflating: training/semantic/000100_10.png
#   inflating: training/semantic/000101_10.png
#   inflating: training/semantic/000102_10.png
#   inflating: training/semantic/000103_10.png
#   inflating: training/semantic/000104_10.png
#   inflating: training/semantic/000105_10.png
#   inflating: training/semantic/000106_10.png
#   inflating: training/semantic/000107_10.png
#   inflating: training/semantic/000108_10.png
#   inflating: training/semantic/000109_10.png
#   inflating: training/semantic/000110_10.png
#   inflating: training/semantic/000111_10.png
#   inflating: training/semantic/000112_10.png
#   inflating: training/semantic/000113_10.png
#   inflating: training/semantic/000114_10.png
#   inflating: training/semantic/000115_10.png
#   inflating: training/semantic/000116_10.png
#   inflating: training/semantic/000117_10.png
#   inflating: training/semantic/000118_10.png
#  extracting: training/semantic/000119_10.png
#   inflating: training/semantic/000120_10.png
#   inflating: training/semantic/000121_10.png
#   inflating: training/semantic/000122_10.png
#  extracting: training/semantic/000123_10.png
#   inflating: training/semantic/000124_10.png
#   inflating: training/semantic/000125_10.png
#   inflating: training/semantic/000126_10.png
#   inflating: training/semantic/000127_10.png
#   inflating: training/semantic/000128_10.png
#   inflating: training/semantic/000129_10.png
#   inflating: training/semantic/000130_10.png
#   inflating: training/semantic/000131_10.png
#   inflating: training/semantic/000132_10.png
#   inflating: training/semantic/000133_10.png
#   inflating: training/semantic/000134_10.png
#   inflating: training/semantic/000135_10.png
#   inflating: training/semantic/000136_10.png
#   inflating: training/semantic/000137_10.png
#   inflating: training/semantic/000138_10.png
#   inflating: training/semantic/000139_10.png
#   inflating: training/semantic/000140_10.png
#   inflating: training/semantic/000141_10.png
#   inflating: training/semantic/000142_10.png
#   inflating: training/semantic/000143_10.png
#   inflating: training/semantic/000144_10.png
#   inflating: training/semantic/000145_10.png
#   inflating: training/semantic/000146_10.png
#   inflating: training/semantic/000147_10.png
#   inflating: training/semantic/000148_10.png
#   inflating: training/semantic/000149_10.png
#   inflating: training/semantic/000150_10.png
#   inflating: training/semantic/000151_10.png
#   inflating: training/semantic/000152_10.png
#   inflating: training/semantic/000153_10.png
#   inflating: training/semantic/000154_10.png
#   inflating: training/semantic/000155_10.png
#   inflating: training/semantic/000156_10.png
#   inflating: training/semantic/000157_10.png
#   inflating: training/semantic/000158_10.png
#   inflating: training/semantic/000159_10.png
#   inflating: training/semantic/000160_10.png
#   inflating: training/semantic/000161_10.png
#   inflating: training/semantic/000162_10.png
#  extracting: training/semantic/000163_10.png
#   inflating: training/semantic/000164_10.png
#   inflating: training/semantic/000165_10.png
#   inflating: training/semantic/000166_10.png
#   inflating: training/semantic/000167_10.png
#   inflating: training/semantic/000168_10.png
#   inflating: training/semantic/000169_10.png
#   inflating: training/semantic/000170_10.png
#   inflating: training/semantic/000171_10.png
#   inflating: training/semantic/000172_10.png
#   inflating: training/semantic/000173_10.png
#   inflating: training/semantic/000174_10.png
#   inflating: training/semantic/000175_10.png
#   inflating: training/semantic/000176_10.png
#   inflating: training/semantic/000177_10.png
#   inflating: training/semantic/000178_10.png
#   inflating: training/semantic/000179_10.png
#   inflating: training/semantic/000180_10.png
#   inflating: training/semantic/000181_10.png
#   inflating: training/semantic/000182_10.png
#   inflating: training/semantic/000183_10.png
#   inflating: training/semantic/000184_10.png
#   inflating: training/semantic/000185_10.png
#  extracting: training/semantic/000186_10.png
#   inflating: training/semantic/000187_10.png
#   inflating: training/semantic/000188_10.png
#   inflating: training/semantic/000189_10.png
#   inflating: training/semantic/000190_10.png
#   inflating: training/semantic/000191_10.png
#   inflating: training/semantic/000192_10.png
#   inflating: training/semantic/000193_10.png
#   inflating: training/semantic/000194_10.png
#   inflating: training/semantic/000195_10.png
#   inflating: training/semantic/000196_10.png
#   inflating: training/semantic/000197_10.png
#   inflating: training/semantic/000198_10.png
#   inflating: training/semantic/000199_10.png
#    creating: training/semantic_rgb/
#   inflating: training/semantic_rgb/000000_10.png
#   inflating: training/semantic_rgb/000001_10.png
#   inflating: training/semantic_rgb/000002_10.png
#   inflating: training/semantic_rgb/000003_10.png
#   inflating: training/semantic_rgb/000004_10.png
#   inflating: training/semantic_rgb/000005_10.png
#   inflating: training/semantic_rgb/000006_10.png
#   inflating: training/semantic_rgb/000007_10.png
#   inflating: training/semantic_rgb/000008_10.png
#   inflating: training/semantic_rgb/000009_10.png
#   inflating: training/semantic_rgb/000010_10.png
#   inflating: training/semantic_rgb/000011_10.png
#   inflating: training/semantic_rgb/000012_10.png
#   inflating: training/semantic_rgb/000013_10.png
#   inflating: training/semantic_rgb/000014_10.png
#   inflating: training/semantic_rgb/000015_10.png
#   inflating: training/semantic_rgb/000016_10.png
#   inflating: training/semantic_rgb/000017_10.png
#   inflating: training/semantic_rgb/000018_10.png
#   inflating: training/semantic_rgb/000019_10.png
#   inflating: training/semantic_rgb/000020_10.png
#   inflating: training/semantic_rgb/000021_10.png
#   inflating: training/semantic_rgb/000022_10.png
#   inflating: training/semantic_rgb/000023_10.png
#   inflating: training/semantic_rgb/000024_10.png
#   inflating: training/semantic_rgb/000025_10.png
#   inflating: training/semantic_rgb/000026_10.png
#   inflating: training/semantic_rgb/000027_10.png
#   inflating: training/semantic_rgb/000028_10.png
#   inflating: training/semantic_rgb/000029_10.png
#   inflating: training/semantic_rgb/000030_10.png
#   inflating: training/semantic_rgb/000031_10.png
#   inflating: training/semantic_rgb/000032_10.png
#   inflating: training/semantic_rgb/000033_10.png
#   inflating: training/semantic_rgb/000034_10.png
#   inflating: training/semantic_rgb/000035_10.png
#   inflating: training/semantic_rgb/000036_10.png
#   inflating: training/semantic_rgb/000037_10.png
#   inflating: training/semantic_rgb/000038_10.png
#   inflating: training/semantic_rgb/000039_10.png
#   inflating: training/semantic_rgb/000040_10.png
#   inflating: training/semantic_rgb/000041_10.png
#   inflating: training/semantic_rgb/000042_10.png
#   inflating: training/semantic_rgb/000043_10.png
#   inflating: training/semantic_rgb/000044_10.png
#   inflating: training/semantic_rgb/000045_10.png
#   inflating: training/semantic_rgb/000046_10.png
#   inflating: training/semantic_rgb/000047_10.png
#   inflating: training/semantic_rgb/000048_10.png
#   inflating: training/semantic_rgb/000049_10.png
#   inflating: training/semantic_rgb/000050_10.png
#   inflating: training/semantic_rgb/000051_10.png
#   inflating: training/semantic_rgb/000052_10.png
#   inflating: training/semantic_rgb/000053_10.png
#   inflating: training/semantic_rgb/000054_10.png
#   inflating: training/semantic_rgb/000055_10.png
#   inflating: training/semantic_rgb/000056_10.png
#   inflating: training/semantic_rgb/000057_10.png
#   inflating: training/semantic_rgb/000058_10.png
#   inflating: training/semantic_rgb/000059_10.png
#   inflating: training/semantic_rgb/000060_10.png
#   inflating: training/semantic_rgb/000061_10.png
#   inflating: training/semantic_rgb/000062_10.png
#   inflating: training/semantic_rgb/000063_10.png
#   inflating: training/semantic_rgb/000064_10.png
#   inflating: training/semantic_rgb/000065_10.png
#   inflating: training/semantic_rgb/000066_10.png
#   inflating: training/semantic_rgb/000067_10.png
#   inflating: training/semantic_rgb/000068_10.png
#   inflating: training/semantic_rgb/000069_10.png
#   inflating: training/semantic_rgb/000070_10.png
#   inflating: training/semantic_rgb/000071_10.png
#   inflating: training/semantic_rgb/000072_10.png
#   inflating: training/semantic_rgb/000073_10.png
#   inflating: training/semantic_rgb/000074_10.png
#   inflating: training/semantic_rgb/000075_10.png
#   inflating: training/semantic_rgb/000076_10.png
#   inflating: training/semantic_rgb/000077_10.png
#   inflating: training/semantic_rgb/000078_10.png
#   inflating: training/semantic_rgb/000079_10.png
#   inflating: training/semantic_rgb/000080_10.png
#   inflating: training/semantic_rgb/000081_10.png
#   inflating: training/semantic_rgb/000082_10.png
#   inflating: training/semantic_rgb/000083_10.png
#   inflating: training/semantic_rgb/000084_10.png
#   inflating: training/semantic_rgb/000085_10.png
#   inflating: training/semantic_rgb/000086_10.png
#   inflating: training/semantic_rgb/000087_10.png
#   inflating: training/semantic_rgb/000088_10.png
#   inflating: training/semantic_rgb/000089_10.png
#   inflating: training/semantic_rgb/000090_10.png
#   inflating: training/semantic_rgb/000091_10.png
#   inflating: training/semantic_rgb/000092_10.png
#   inflating: training/semantic_rgb/000093_10.png
#   inflating: training/semantic_rgb/000094_10.png
#   inflating: training/semantic_rgb/000095_10.png
#   inflating: training/semantic_rgb/000096_10.png
#   inflating: training/semantic_rgb/000097_10.png
#   inflating: training/semantic_rgb/000098_10.png
#   inflating: training/semantic_rgb/000099_10.png
#   inflating: training/semantic_rgb/000100_10.png
#   inflating: training/semantic_rgb/000101_10.png
#   inflating: training/semantic_rgb/000102_10.png
#   inflating: training/semantic_rgb/000103_10.png
#   inflating: training/semantic_rgb/000104_10.png
#   inflating: training/semantic_rgb/000105_10.png
#   inflating: training/semantic_rgb/000106_10.png
#   inflating: training/semantic_rgb/000107_10.png
#   inflating: training/semantic_rgb/000108_10.png
#   inflating: training/semantic_rgb/000109_10.png
#   inflating: training/semantic_rgb/000110_10.png
#   inflating: training/semantic_rgb/000111_10.png
#   inflating: training/semantic_rgb/000112_10.png
#   inflating: training/semantic_rgb/000113_10.png
#   inflating: training/semantic_rgb/000114_10.png
#   inflating: training/semantic_rgb/000115_10.png
#   inflating: training/semantic_rgb/000116_10.png
#   inflating: training/semantic_rgb/000117_10.png
#   inflating: training/semantic_rgb/000118_10.png
#   inflating: training/semantic_rgb/000119_10.png
#   inflating: training/semantic_rgb/000120_10.png
#   inflating: training/semantic_rgb/000121_10.png
#   inflating: training/semantic_rgb/000122_10.png
#   inflating: training/semantic_rgb/000123_10.png
#   inflating: training/semantic_rgb/000124_10.png
#   inflating: training/semantic_rgb/000125_10.png
#   inflating: training/semantic_rgb/000126_10.png
#   inflating: training/semantic_rgb/000127_10.png
#   inflating: training/semantic_rgb/000128_10.png
#   inflating: training/semantic_rgb/000129_10.png
#   inflating: training/semantic_rgb/000130_10.png
#   inflating: training/semantic_rgb/000131_10.png
#   inflating: training/semantic_rgb/000132_10.png
#   inflating: training/semantic_rgb/000133_10.png
#   inflating: training/semantic_rgb/000134_10.png
#   inflating: training/semantic_rgb/000135_10.png
#   inflating: training/semantic_rgb/000136_10.png
#   inflating: training/semantic_rgb/000137_10.png
#   inflating: training/semantic_rgb/000138_10.png
#   inflating: training/semantic_rgb/000139_10.png
#   inflating: training/semantic_rgb/000140_10.png
#   inflating: training/semantic_rgb/000141_10.png
#   inflating: training/semantic_rgb/000142_10.png
#   inflating: training/semantic_rgb/000143_10.png
#   inflating: training/semantic_rgb/000144_10.png
#   inflating: training/semantic_rgb/000145_10.png
#   inflating: training/semantic_rgb/000146_10.png
#   inflating: training/semantic_rgb/000147_10.png
#   inflating: training/semantic_rgb/000148_10.png
#   inflating: training/semantic_rgb/000149_10.png
#   inflating: training/semantic_rgb/000150_10.png
#   inflating: training/semantic_rgb/000151_10.png
#   inflating: training/semantic_rgb/000152_10.png
#   inflating: training/semantic_rgb/000153_10.png
#   inflating: training/semantic_rgb/000154_10.png
#   inflating: training/semantic_rgb/000155_10.png
#   inflating: training/semantic_rgb/000156_10.png
#   inflating: training/semantic_rgb/000157_10.png
#   inflating: training/semantic_rgb/000158_10.png
#   inflating: training/semantic_rgb/000159_10.png
#   inflating: training/semantic_rgb/000160_10.png
#   inflating: training/semantic_rgb/000161_10.png
#   inflating: training/semantic_rgb/000162_10.png
#   inflating: training/semantic_rgb/000163_10.png
#   inflating: training/semantic_rgb/000164_10.png
#   inflating: training/semantic_rgb/000165_10.png
#   inflating: training/semantic_rgb/000166_10.png
#   inflating: training/semantic_rgb/000167_10.png
#   inflating: training/semantic_rgb/000168_10.png
#   inflating: training/semantic_rgb/000169_10.png
#   inflating: training/semantic_rgb/000170_10.png
#   inflating: training/semantic_rgb/000171_10.png
#   inflating: training/semantic_rgb/000172_10.png
#   inflating: training/semantic_rgb/000173_10.png
#   inflating: training/semantic_rgb/000174_10.png
#   inflating: training/semantic_rgb/000175_10.png
#   inflating: training/semantic_rgb/000176_10.png
#   inflating: training/semantic_rgb/000177_10.png
#   inflating: training/semantic_rgb/000178_10.png
#   inflating: training/semantic_rgb/000179_10.png
#   inflating: training/semantic_rgb/000180_10.png
#   inflating: training/semantic_rgb/000181_10.png
#   inflating: training/semantic_rgb/000182_10.png
#   inflating: training/semantic_rgb/000183_10.png
#   inflating: training/semantic_rgb/000184_10.png
#   inflating: training/semantic_rgb/000185_10.png
#   inflating: training/semantic_rgb/000186_10.png
#   inflating: training/semantic_rgb/000187_10.png
#   inflating: training/semantic_rgb/000188_10.png
#   inflating: training/semantic_rgb/000189_10.png
#   inflating: training/semantic_rgb/000190_10.png
#   inflating: training/semantic_rgb/000191_10.png
#   inflating: training/semantic_rgb/000192_10.png
#   inflating: training/semantic_rgb/000193_10.png
#   inflating: training/semantic_rgb/000194_10.png
#   inflating: training/semantic_rgb/000195_10.png
#   inflating: training/semantic_rgb/000196_10.png
#   inflating: training/semantic_rgb/000197_10.png
#   inflating: training/semantic_rgb/000198_10.png
#   inflating: training/semantic_rgb/000199_10.png

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import transforms
import torchvision.models.segmentation as segmentation
import matplotlib.pyplot as plt
from PIL import Image
import os
import cv2
import numpy as np
from torch.utils.data import Dataset, DataLoader, random_split
from tqdm import tqdm
import logging

# %% [markdown]
# # Preprocess masks

# %%
# Define a dictionary mapping RGB colors to class labels
# The key is the (R, G, B) tuple, and the value is the corresponding class label
color_map = {
    (128, 64, 128): 1,    # Road
    (35,142,107): 2,    # Sidewalk
    (70, 70, 70): 3,      # Building
    (60,20,220): 4,   # Wall
    (153, 153, 153): 5,   # Fence
    (153, 153, 190): 6,   # Vegetation
    (0,220,220): 7,     # Terrain
    (142,0,0): 8,       # Sky
    (100, 100, 150): 9,       # Person
    (152, 251, 152): 10,      # Car
    (180, 130, 70): 11,    # Bicycle
    (232, 35, 244): 12,    # Motorcycle
    (0,0,0): 0,   # Background (can be 0)
}

# %%
# Path to the folder with RGB masks
mask_folder = '/content/training/semantic_rgb'
output_mask_folder = '/content/preprocessed_masks'
os.makedirs(output_mask_folder)
n = 0
total = len(os.listdir(mask_folder))
# Loop through all mask images
for mask_filename in os.listdir(mask_folder):
    if mask_filename.endswith(".png"):
        mask_path = os.path.join(mask_folder, mask_filename)
        mask_image = cv2.imread(mask_path)

        # Create empty integer mask
        height, width, _ = mask_image.shape
        integer_mask = np.zeros((height, width), dtype=np.uint8)

        # Convert RGB to class labels
        for i in range(height):
            for j in range(width):
                rgb_value = tuple(mask_image[i, j])
                if rgb_value in color_map:
                    integer_mask[i, j] = color_map[rgb_value]
                else:
                    integer_mask[i, j] = 0  # Background

        # Save the integer mask
        output_mask_path = os.path.join(output_mask_folder, mask_filename)
        cv2.imwrite(output_mask_path, integer_mask)
        n+=1
        print(str(n) +'/'+ str(total))
# Out:
# 1/200
# 2/200
# 3/200
# 4/200
# 5/200
# 6/200
# 7/200
# 8/200
# 9/200
# 10/200
# 11/200
# 12/200
# 13/200
# 14/200
# 15/200
# 16/200
# 17/200
# 18/200
# 19/200
# 20/200
# 21/200
# 22/200
# 23/200
# 24/200
# 25/200
# 26/200
# 27/200
# 28/200
# 29/200
# 30/200
# 31/200
# 32/200
# 33/200
# 34/200
# 35/200
# 36/200
# 37/200
# 38/200
# 39/200
# 40/200
# 41/200
# 42/200
# 43/200
# 44/200
# 45/200
# 46/200
# 47/200
# 48/200
# 49/200
# 50/200
# 51/200
# 52/200
# 53/200
# 54/200
# 55/200
# 56/200
# 57/200
# 58/200
# 59/200
# 60/200
# 61/200
# 62/200
# 63/200
# 64/200
# 65/200
# 66/200
# 67/200
# 68/200
# 69/200
# 70/200
# 71/200
# 72/200
# 73/200
# 74/200
# 75/200
# 76/200
# 77/200
# 78/200
# 79/200
# 80/200
# 81/200
# 82/200
# 83/200
# 84/200
# 85/200
# 86/200
# 87/200
# 88/200
# 89/200
# 90/200
# 91/200
# 92/200
# 93/200
# 94/200
# 95/200
# 96/200
# 97/200
# 98/200
# 99/200
# 100/200
# 101/200
# 102/200
# 103/200
# 104/200
# 105/200
# 106/200
# 107/200
# 108/200
# 109/200
# 110/200
# 111/200
# 112/200
# 113/200
# 114/200
# 115/200
# 116/200
# 117/200
# 118/200
# 119/200
# 120/200
# 121/200
# 122/200
# 123/200
# 124/200
# 125/200
# 126/200
# 127/200
# 128/200
# 129/200
# 130/200
# 131/200
# 132/200
# 133/200
# 134/200
# 135/200
# 136/200
# 137/200
# 138/200
# 139/200
# 140/200
# 141/200
# 142/200
# 143/200
# 144/200
# 145/200
# 146/200
# 147/200
# 148/200
# 149/200
# 150/200
# 151/200
# 152/200
# 153/200
# 154/200
# 155/200
# 156/200
# 157/200
# 158/200
# 159/200
# 160/200
# 161/200
# 162/200
# 163/200
# 164/200
# 165/200
# 166/200
# 167/200
# 168/200
# 169/200
# 170/200
# 171/200
# 172/200
# 173/200
# 174/200
# 175/200
# 176/200
# 177/200
# 178/200
# 179/200
# 180/200
# 181/200
# 182/200
# 183/200
# 184/200
# 185/200
# 186/200
# 187/200
# 188/200
# 189/200
# 190/200
# 191/200
# 192/200
# 193/200
# 194/200
# 195/200
# 196/200
# 197/200
# 198/200
# 199/200
# 200/200

# %% [markdown]
# # KITTI dataset class

# %%
class KITTIdataset(Dataset):
    def __init__(self,image_dir, mask_dir, transform=None, mask_transform=None, image_size=(256, 256)):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.mask_transform = mask_transform
        self.image_size = image_size

        self.image_names = sorted([f for f in os.listdir(image_dir) if f.endswith(('.png', '.jpg', '.jpeg'))])
        self.mask_names = sorted([f for f in os.listdir(mask_dir) if f.endswith(('.png', '.jpg', '.jpeg'))])

        assert len(self.image_names) == len(self.mask_names), "Mismatch between image and mask count!"

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.image_names[idx])
        mask_path = os.path.join(self.mask_dir, self.mask_names[idx])

        image = Image.open(img_path)
        mask = Image.open(mask_path)

        if self.image_size:
            image = image.resize(self.image_size)
            mask = mask.resize(self.image_size)

        if self.transform:
            image = self.transform(image)
        if self.mask_transform:
            mask = self.mask_transform(mask)

        return image, mask

# %% [markdown]
# # Model class

# %%
class DeepLabV3Plus(nn.Module):
    def __init__(self, num_classes = 13):
        super(DeepLabV3Plus, self).__init__()
        self.model = segmentation.deeplabv3_resnet101(pretrained=True)
        self.model.classifier[4] = nn.Conv2d(256, num_classes, kernel_size=(1, 1), stride=(1, 1))

    def forward(self, x):
        return self.model(x)['out']

# %% [markdown]
# # Define instances and variables

# %%
image_dir = '/content/training/image_2'
mask_dir = '/content/preprocessed_masks'
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
EPOCHS = 50
BATCH_SIZE = 8
NUM_CLASSES = 13
LEARNING_RATE = 1e-3
IMAGE_SIZE = (256, 256)
CHECKPOINT_DIR = "./experiments/"

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((256, 256)),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

mask_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((256, 256))
])

dataset = KITTIdataset(image_dir=image_dir, mask_dir=mask_dir,
                       transform=transform, mask_transform=mask_transform)

num_img = len(dataset)
train_size = int(0.1*num_img)
val_size = int(0.1*num_img)
test_size = num_img - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

model = DeepLabV3Plus(NUM_CLASSES).to(DEVICE)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), LEARNING_RATE)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DeepLabV3_ResNet101_Weights.COCO_WITH_VOC_LABELS_V1`. You can also use `weights=DeepLabV3_ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/deeplabv3_resnet101_coco-586e9e4e.pth" to /root/.cache/torch/hub/checkpoints/deeplabv3_resnet101_coco-586e9e4e.pth
# 100%|██████████| 233M/233M [00:02<00:00, 113MB/s]

# %%
import time
from tqdm import tqdm  # Progress bar

num_epochs = 10  # Adjust number of epochs
print_freq = 10  # Print loss every 10 batches

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    running_loss = 0.0
    start_time = time.time()

    # tqdm progress bar for better visibility
    progress_bar = tqdm(enumerate(train_loader), total=len(train_loader), desc=f"Epoch {epoch+1}/{num_epochs}")

    for batch_idx, (images, masks) in progress_bar:
        images, masks = images.to(DEVICE), masks.to(DEVICE)

        optimizer.zero_grad()  # Zero the gradients
        outputs = model(images)['out']  # Forward pass
        loss = criterion(outputs, masks)  # Compute loss
        loss.backward()  # Backpropagation
        optimizer.step()  # Optimize the weights

        running_loss += loss.item()

        # Print progress every `print_freq` batches
        if (batch_idx + 1) % print_freq == 0 or batch_idx == len(train_loader) - 1:
            avg_loss = running_loss / (batch_idx + 1)
            progress_bar.set_postfix(loss=f"{avg_loss:.4f}")

    # Calculate and print epoch summary
    epoch_loss = running_loss / len(train_loader)
    epoch_time = time.time() - start_time
    print(f"Epoch [{epoch+1}/{num_epochs}] - Loss: {epoch_loss:.4f} - Time: {epoch_time:.2f}s")

    # Save model at the end
torch.save(model.state_dict(), f"deeplabv3_epoch{epoch+1}.pth")
# Out:
# Epoch 1/10:   0%|          | 0/1 [00:43<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1e9e172a3b9d> in <cell line: 0>()
#      17
#      18         optimizer.zero_grad()  # Zero the gradients
# ---> 19         outputs = model(images)['out']  # Forward pass
#      20         loss = criterion(outputs, masks)  # Compute loss
#      21         loss.backward()  # Backpropagation
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-8-3ff0e573b6c1> in forward(self, x)
#       6
#       7     def forward(self, x):
# ----> 8         return self.model(x)['out']
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torchvision/models/segmentation/_utils.py in forward(self, x)
#      21         input_shape = x.shape[-2:]
#      22         # contract: features is a dict of tensors
# ---> 23         features = self.backbone(x)
#      24
#      25         result = OrderedDict()
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py in forward(self, x)
#      67         out = OrderedDict()
#      68         for name, module in self.items():
# ---> 69             x = module(x)
#      70             if name in self.return_layers:
#      71                 out_name = self.return_layers[name]
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torchvision/models/resnet.py in forward(self, x)
#     144         identity = x
#     145
# --> 146         out = self.conv1(x)
#     147         out = self.bn1(out)
#     148         out = self.relu(out)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# KeyboardInterrupt:
